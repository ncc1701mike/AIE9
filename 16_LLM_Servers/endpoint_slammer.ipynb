# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
# This is the severless model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
# model_endpoint = "accounts/michaelbryandoran-po/deployments/n1d99scx"
model_endpoint = "accounts/fireworks/models/gpt-oss-20b" # Serverless

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x1123d2390>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x1123d2d20>
# It’s a classic tongue‑twister that triples up the words “woodchuck” and “wood.”  In everyday play the answer is the same phrase that the riddle’s written with:
#
# > **“A woodchuck would chuck as much wood as a woodchuck could chuck, if a woodchuck could chuck wood.”**
#
# So, in the world of jokes, there’s no “exact quantity”—the answer is simply a mirror of the question.
#
# If you’d like a bit of semi‑scientific fun, a 1976 calculation by wildlife scientist Richard Thomas estimated that, based on the size of a woodchuck’s burrow, a single animal could move about **700 lb (≈320 kg) of dirt** in a day.  Since wood is less dense than dirt, the volume of wood a typical woodchuck could chuck would be roughly 1.5–2 m³ (about 53–70 ft³).  Of course, that figure is mostly an estimate of how much material a woodchuck could dig through—not an official “wood‑chucking” capacity!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 5)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 1 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-006160180de44c12addf6b40a3022595"}
# Response 3: According to the classic tongue‑twister “How much wood would...
# Response 2: A classic tongue‑twister, but it turns out there is a “real”...
# Response 4: ### The Great Wood‑Chucking Question
#
# > “How much wood could...
