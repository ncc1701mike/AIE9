# %% [markdown]
# # Session 14: MCP-Powered X Post Summarizer
#
# ## Building a LangGraph Agent with GitHub MCP Tools, X API Tools, and Memory
#
# ## Learning Objectives:
#
# - **Ingest MCP servers as LangGraph tools** using `langchain-mcp-adapters` to connect to the GitHub MCP Server and use its tools programmatically
# - **Wrap the X (Twitter) API as a LangChain tool** using the `@tool` decorator so a LangGraph agent can search and retrieve public posts
# - **Build a LangGraph agent with memory** that combines MCP-sourced tools and custom tools, using `MemorySaver` for short-term conversational memory
# - **Orchestrate a full workflow through the agent** — search X posts, generate summaries, create a GitHub repo, commit files, branch, and open a PR — all via natural language
#
# ## Overview
#
# In this notebook, you will build a **LangGraph ReAct agent** that has access to two categories of tools:
#
# 1. **GitHub MCP tools** — loaded from the official GitHub MCP Server via `langchain-mcp-adapters`. These replace manual `git` commands with tool calls the agent can invoke (create repos, commit files, create branches, open PRs).
# 2. **X API tools** — custom Python functions wrapped with the `@tool` decorator that call the X API v2 directly to search and retrieve posts.
#
# The agent uses **`MemorySaver`** for short-term memory so it can maintain context across multi-step workflows within a conversation thread.
#
# There will be one breakout room with two phases:
#
# - 🤝 Phase 1: Setup, Tools & Agent Construction
#   - Task 1: Dependencies & Environment
#   - Task 2: X API as LangChain Tools
#   - Task 3: Connect to GitHub MCP Server & Load Tools
#   - Task 4: Build the LangGraph Agent with Memory
#   - Task 5: Test the Agent — Search & Summarize X Posts
#   - Activity #1: Extend the Agent with a Custom X API Tool
# - 🤝 Phase 2: MCP Workflow Through the Agent
#   - Task 6: Create a GitHub Repository
#   - Task 7: Commit the Summary
#   - Task 8: Create a Feature Branch & Add Metadata
#   - Task 9: Open a Pull Request
#   - Task 10: Commit the X API Script
#   - Task 11: Update the README
#   - Activity #1: Multi-Account Comparison Pipeline

# %% [markdown]
# ---
#
# # 🤝 Breakout Room
# ## Setup, Tools & Agent Construction

# %% [markdown]
# ## Task 1: Dependencies & Environment
#
# We need:
# - `langchain-mcp-adapters` to connect to MCP servers and convert their tools into LangChain tools
# - `langgraph` for our agent graph with memory
# - `langchain-openai` for our LLM
# - `requests` for the X API calls
# - `nest-asyncio` for async MCP operations inside Jupyter
#
# > NOTE: Create a `.env` file in this directory with `X_BEARER_TOKEN`, `OPENAI_API_KEY`, and `GITHUB_PAT` before running.
# >
# > Setup references:
# > - GitHub fine-grained PAT guide: [Creating a personal access token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens#creating-a-fine-grained-personal-access-token)
# > - X API Bearer Token setup: [X Developer Portal](https://developer.x.com/en/portal/dashboard) and [X API access tiers](https://developer.x.com/en/products/twitter-api)

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("X_BEARER_TOKEN"):
    os.environ["X_BEARER_TOKEN"] = getpass.getpass("Enter your X Bearer Token:")

if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

if not os.environ.get("GITHUB_PAT"):
    os.environ["GITHUB_PAT"] = getpass.getpass("Enter your GitHub PAT:")

# %%
import nest_asyncio
nest_asyncio.apply()  # Required for async operations in Jupyter

# %% [markdown]
# ### Getting Your Credentials
#
# **GitHub PAT (fine-grained):**
# 1. Open [GitHub Personal Access Tokens (fine-grained)](https://github.com/settings/personal-access-tokens/new).
# 2. Follow [GitHub's PAT setup guide](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens#creating-a-fine-grained-personal-access-token).
# 3. Set repository permissions to at least:
#    - `Contents`: Read and write
#    - `Pull requests`: Read and write
#    - `Metadata`: Read-only
#
# **X Bearer Token:**
# 1. Open the [X Developer Portal](https://developer.x.com/en/portal/dashboard).
# 2. Create/select a Project + App, then go to **Keys and Tokens** to generate a Bearer Token.
# 3. Confirm your plan supports the recent search endpoint (`GET /2/tweets/search/recent`) from the [X API product page](https://developer.x.com/en/products/twitter-api).

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

# Test the connection
response = llm.invoke("Say 'MCP agent ready!' in exactly those words.")
print(response.content)
# Out:
# MCP agent ready!

# %% [markdown]
# ## Task 2: X API as LangChain Tools
#
# Instead of relying on a community-built MCP server for X, we'll call the **X API v2** directly and wrap our functions with the `@tool` decorator. This makes them available to our LangGraph agent as callable tools — just like the MCP tools will be.
#
# This is a key architectural decision: **not everything needs to be an MCP server**. Wrapping a simple API call as a `@tool` is often simpler and more transparent.
#
# **📚 Documentation:**
# - [LangChain Tools Conceptual Guide](https://python.langchain.com/docs/concepts/tools/)
# - [X API v2 Documentation](https://developer.x.com/en/docs/x-api)

# %%
import requests
import json
from langchain_core.tools import tool

BEARER_TOKEN = os.environ.get("X_BEARER_TOKEN")


@tool
def search_recent_posts(query: str, max_results: int = 20) -> str:
    """Search recent X/Twitter posts using the v2 API.
    Returns posts from the last 7 days matching the query.
    Use this for keyword searches, hashtag searches, or general topic searches.

    Args:
        query: The search query (e.g., 'AI safety', '#machinelearning', 'from:AndrewYNg')
        max_results: Number of results to return (10-100, default 20)
    """
    url = "https://api.x.com/2/tweets/search/recent"
    headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
    params = {
        "query": query,
        "max_results": min(max(max_results, 10), 100),
        "tweet.fields": "created_at,public_metrics,author_id,text",
        "expansions": "author_id",
        "user.fields": "name,username",
    }

    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    data = response.json()

    tweets = data.get("data", [])
    if not tweets:
        return "No posts found for this query."

    result_lines = [f"Found {len(tweets)} posts:\n"]
    for t in tweets:
        metrics = t.get("public_metrics", {})
        result_lines.append(
            f"[{t.get('created_at', 'unknown')[:10]}] "
            f"{t['text'][:200]}\n"
            f"  Likes: {metrics.get('like_count', 0)} | "
            f"Retweets: {metrics.get('retweet_count', 0)}"
        )
    return "\n\n".join(result_lines)


@tool
def get_user_posts(username: str, max_results: int = 20) -> str:
    """Get recent original posts (no retweets) from a specific X/Twitter user.
    Use this when you want to see what a specific account has been posting.

    Args:
        username: The X/Twitter handle without the @ sign (e.g., 'AndrewYNg')
        max_results: Number of results to return (10-100, default 20)
    """
    query = f"from:{username} -is:retweet"
    return search_recent_posts.invoke({"query": query, "max_results": max_results})

@tool
def get_user_profile(username: str) -> dict:
    """
    Get a public X profile by username.


    x_api_tools = [search_recent_posts, get_user_posts]
    print(f"Created {len(x_api_tools)} X API tools: {[t.name for t in x_api_tools]}")

    Returns a dict with:
    - display_name
    - bio
    - followers
    - following
    - post_count
    - created_at
    """
    if not BEARER_TOKEN:
        raise RuntimeError("X_BEARER_TOKEN env var is not set")

    url = f"https://api.x.com/2/users/by/username/{username}"
    headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
    params = {
        "user.fields": "description,public_metrics,created_at",
    }

    resp = requests.get(url, headers=headers, params=params, timeout=20)
    if not resp.ok:
        raise RuntimeError(f"X API error {resp.status_code}: {resp.text}")

    data = resp.json().get("data", {})
    metrics = data.get("public_metrics", {})

    return {
        "username": data.get("username"),
        "display_name": data.get("name"),
        "bio": data.get("description"),
        "followers": metrics.get("followers_count"),
        "following": metrics.get("following_count"),
        "post_count": metrics.get("tweet_count"),
        "created_at": data.get("created_at"),
    }

x_api_tools = [search_recent_posts, get_user_posts, get_user_profile]
print(f"Created {len(x_api_tools)} X API tools: {[t.name for t in x_api_tools]}")
# Out:
# Created 3 X API tools: ['search_recent_posts', 'get_user_posts', 'get_user_profile']

# %% [markdown]
# Let's verify our X API tools work before wiring them into the agent:

# %%
# Quick test — fetch recent posts from a public account

result = get_user_posts.invoke({"username": "llm_wizard", "max_results": 10})
print(result[:500])
# Out:
# Found 10 posts:
#
#
# [2026-02-27] @signulll Obviously a hard lined liberal.
#   Likes: 0 | Retweets: 0
#
# [2026-02-27] PR at Claude woke up this morning and chose "based".
#
# https://t.co/I5xB90KNnF
#   Likes: 3 | Retweets: 0
#
# [2026-02-26] @xeophon Maybe it scans your X profile to generate names. Wouldn't be surprised.
#   Likes: 3 | Retweets: 0
#
# [2026-02-26] https://t.co/r6VNsKy0KZ https://t.co/NrhYwynUIL
#   Likes: 4 | Retweets: 0
#
# [2026-02-26] @TheZachMueller It's not your fault, I just need you to fix it -

# %% [markdown]
# ## Task 3: Connect to GitHub MCP Server & Load Tools
#
# Now we'll connect to the **GitHub MCP Server** — an official, GitHub-maintained MCP server that gives agents the ability to manage repositories, issues, pull requests, and more.
#
# We use `langchain-mcp-adapters` to:
# 1. Connect to the remote GitHub MCP server over HTTP
# 2. Automatically convert all MCP tools into LangChain-compatible tools
#
# This is the key MCP integration point — instead of writing custom GitHub API wrappers, we get a full set of tools for free just by connecting to the MCP server.
#
# **📚 Documentation:**
# - [langchain-mcp-adapters](https://github.com/langchain-ai/langchain-mcp-adapters)
# - [GitHub MCP Server](https://github.com/github/github-mcp-server)
# - [Model Context Protocol Specification](https://modelcontextprotocol.io/)

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

# Connect to the GitHub MCP server using Streamable HTTP transport
# The server exposes GitHub operations as MCP tools that our agent can call
mcp_client = MultiServerMCPClient(
    {
        "github": {
            "transport": "http",
            "url": "https://api.githubcopilot.com/mcp/",
            "headers": {
                "Authorization": f"Bearer {os.environ['GITHUB_PAT']}",
            },
        }
    }
)

# Load all tools from the MCP server
github_mcp_tools = await mcp_client.get_tools()

print(f"Loaded {len(github_mcp_tools)} GitHub MCP tools:\n")
for t in github_mcp_tools:
    print(f"  - {t.name}: {t.description[:80]}...")

# %% [markdown]
# ### Key GitHub MCP Tools
#
# The MCP server exposes many tools, but the key ones we'll use are:
#
# | MCP Tool | Replaces (Git CLI) | What It Does |
# |---|---|---|
# | `create_repository` | `git init` + GitHub UI | Creates a new repo on your account |
# | `create_or_update_file` | `git add` + `git commit` + `git push` | Commits a file directly to a branch |
# | `create_branch` | `git checkout -b` | Creates a new branch |
# | `create_pull_request` | `gh pr create` | Opens a PR from one branch to another |
# | `search_repositories` | `gh repo list` | Searches across your repos |
# | `get_file_contents` | `git show` / `cat` | Reads a file from a repo |
# | `list_commits` | `git log` | Shows commit history |

# %% [markdown]
# ## Task 4: Build the LangGraph Agent with Memory
#
# Now we combine **both tool sets** into a single LangGraph agent:
# - **X API tools** — custom `@tool` functions for searching posts
# - **GitHub MCP tools** — loaded from the MCP server via `langchain-mcp-adapters`
#
# We add **`MemorySaver`** for short-term memory so the agent remembers context across the multi-step workflow (e.g., it fetches posts in one turn, summarizes them in the next, and commits the summary in a third).
#
# The architecture follows the standard LangGraph ReAct pattern from Sessions 4-6:
#
# ```
# ┌─────────┐     ┌───────────┐
# │  START   │────▶│   Agent   │◀──────────────┐
# └─────────┘     │  (LLM +   │               │
#                 │   tools)  │               │
#                 └─────┬─────┘               │
#                       │                     │
#                has tool calls?              │
#                 /           \               │
#               yes            no             │
#               /               \             │
#     ┌─────────────┐     ┌─────────┐        │
#     │  Tool Node  │     │   END   │        │
#     │ (X API +    │     └─────────┘        │
#     │  GitHub MCP)│─────────────────────────┘
#     └─────────────┘
# ```
#
# **📚 Documentation:**
# - [LangGraph ReAct Agent](https://langchain-ai.github.io/langgraph/tutorials/introduction/)
# - [MemorySaver (Checkpointing)](https://langchain-ai.github.io/langgraph/concepts/persistence/)
# - [ToolNode Prebuilt](https://langchain-ai.github.io/langgraph/reference/prebuilt/#langgraph.prebuilt.tool_node.ToolNode)

# %%
from typing import Annotated, Literal
from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# Combine all tools: X API tools + GitHub MCP tools
all_tools = x_api_tools + github_mcp_tools
print(f"Total tools available to agent: {len(all_tools)}")
print(f"  X API tools: {[t.name for t in x_api_tools]}")
print(f"  GitHub MCP tools: {[t.name for t in github_mcp_tools]}")
# Out:
# Total tools available to agent: 46
#   X API tools: ['search_recent_posts', 'get_user_posts', 'get_user_profile']
#   GitHub MCP tools: ['add_comment_to_pending_review', 'add_issue_comment', 'add_reply_to_pull_request_comment', 'assign_copilot_to_issue', 'create_branch', 'create_or_update_file', 'create_pull_request', 'create_pull_request_with_copilot', 'create_repository', 'delete_file', 'fork_repository', 'get_commit', 'get_copilot_job_status', 'get_file_contents', 'get_label', 'get_latest_release', 'get_me', 'get_release_by_tag', 'get_tag', 'get_team_members', 'get_teams', 'issue_read', 'issue_write', 'list_branches', 'list_commits', 'list_issue_types', 'list_issues', 'list_pull_requests', 'list_releases', 'list_tags', 'merge_pull_request', 'pull_request_read', 'pull_request_review_write', 'push_files', 'request_copilot_review', 'search_code', 'search_issues', 'search_pull_requests', 'search_repositories', 'search_users', 'sub_issue_write', 'update_pull_request', 'update_pull_request_branch']

# %%
# Step 1: Define the Agent State
class AgentState(TypedDict):
    messages: Annotated[list, add_messages]


# Step 2: Define the system prompt
SYSTEM_PROMPT = """You are an AI assistant that can search X/Twitter posts and manage GitHub repositories.

You have two categories of tools:
1. X API tools: get_user_profile,search_recent_posts, get_user_posts — for searching and retrieving X/Twitter posts
2. GitHub MCP tools: for creating repos, committing files, creating branches, opening PRs, etc.

When asked to summarize posts, retrieve them first using the X API tools, then provide a structured
markdown summary with: Overview, Key Themes, Notable Posts, and Summary Statistics.

When asked to perform GitHub operations, use the appropriate GitHub MCP tool.
Always use the available tools when appropriate. Be concise in your responses."""


# Step 3: Bind tools to the LLM
llm_with_tools = llm.bind_tools(all_tools)


# Step 4: Define the agent node
def agent_node(state: AgentState):
    """The agent node — calls the LLM with the current conversation and available tools."""
    messages = [SystemMessage(content=SYSTEM_PROMPT)] + state["messages"]
    response = llm_with_tools.invoke(messages)
    return {"messages": [response]}


# Step 5: Define the tool node
tool_node = ToolNode(all_tools, handle_tool_errors=True)


# Step 6: Define routing logic
def should_continue(state: AgentState) -> Literal["tools", "end"]:
    """Determine whether to call tools or end the conversation."""
    last_message = state["messages"][-1]
    if hasattr(last_message, "tool_calls") and last_message.tool_calls:
        return "tools"
    return "end"


# Step 7: Build the graph
workflow = StateGraph(AgentState)

workflow.add_node("agent", agent_node)
workflow.add_node("tools", tool_node)

workflow.add_edge(START, "agent")
workflow.add_conditional_edges("agent", should_continue, {"tools": "tools", "end": END})
workflow.add_edge("tools", "agent")

# Compile with MemorySaver for short-term memory across turns
checkpointer = MemorySaver()
agent = workflow.compile(checkpointer=checkpointer)

print("Agent compiled with memory and tools!")
# Out:
# Agent compiled with memory and tools!

# %% [markdown]
# Let's visualize the graph to confirm our architecture:

# %%
from IPython.display import Image, display

display(Image(agent.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Helper function for running the agent
#
# We'll use a single `thread_id` throughout the notebook so the agent remembers previous interactions (short-term memory via the checkpointer).

# %%
# Use a consistent thread_id so the agent remembers context across all tasks
config = {"configurable": {"thread_id": "mcp-workflow-1"}}


async def ask_agent(user_message: str) -> str:
    """Send a message to the agent and return its final response."""
    response = await agent.ainvoke(
        {"messages": [HumanMessage(content=user_message)]},
        config,
    )
    return response["messages"][-1].content

# %% [markdown]
# ## Task 5: Test the Agent — Search & Summarize X Posts
#
# Let's put the agent through its paces. First, we'll ask it to search for posts and generate a summary. Because we're using `MemorySaver` with a consistent `thread_id`, the agent will remember the posts it found when we ask it to summarize them.

# %%
# Ask the agent to fetch posts — it will use the get_user_posts tool
result = await ask_agent("Get recent posts from @llm_wizard on X/Twitter.")
print(result[:1000])
# Out:
# Here are recent posts from @llm_wizard on X/Twitter:
#
# - Commentary on a "hard lined liberal" and a humorous take on a PR at Claude choosing "based."
# - Discussion about generating names possibly by scanning X profiles.
# - Sharing links and mentioning colleagues about fixing cluster names.
# - Expressing preference for using Lambda over Brev for personal projects.
# - Reflecting on the feeling of "takeoff" and tight vibes with friends.
# - Sharing an intriguing link with a watchful emoji.
# - Praising an experiment with little downside.
# - Advising to stop doing things one doesn't like if views aren't the motivation.
# - Expressing alignment or opposition to certain ideas, with a nod to anthropology.
# - Mentioning Claude Code being "possessed by ghosts."
# - Commenting on Anthropic building OpenClaw as expected.
# - Discussing building intuition with a new dialect specific to models.
# - Sharing excitement about a useful tool.
# - Predicting future "Claude's not feeling well" days instead of sick days.
# - Obs

# %%
# Ask the agent to get the user profile — it will use the get_user_profile tool
profile = await ask_agent("Get the profile of @llm_wizard on X/Twitter.")
print(profile)
# Out:
# Profile of @llm_wizard on X/Twitter:
#
# - Display Name: Chris 🇨🇦
# - Bio: Open Source Model Lover @ NVIDIA AI. Views my own.
# - Followers: 1,738
# - Following: 577
# - Total Posts: 5,154
# - Account Created: June 7, 2021
#
# Let me know if you need more information or further assistance.

# %%
# Ask the agent to summarize — it remembers the posts from the previous turn!
summary = await ask_agent(
    "Now as a pirate,summarize those posts into a structured markdown report with sections for: "
    "Overview, Key Themes, Notable Posts, and Summary Statistics. "
    "Format it so it can be saved directly as a summary.md file."
)
print(summary)
# Out:
# ```markdown
# # Summary of Recent Posts by @llm_wizard
#
# ## Overview
# Arrr, matey! Here be a roundup of the latest messages from the digital seas of @llm_wizard, a true buccaneer of open source models and AI adventures. Chris, the Canadian corsair, shares thoughts, jests, and insights from the vast ocean of technology and life.
#
# ## Key Themes
# - **AI and Open Source Models:** Chris be a lover of open source models, often talkin' 'bout Claude and Anthropic's ventures.
# - **Work and Tools:** Mentions of Brev and Lambda for spinnin' up spot instances in the day job.
# - **Community and Collaboration:** Calls out to mates for fixin' cluster names and shares vibes with fellow sailors.
# - **Philosophy and Motivation:** Advises to steer clear of tasks ye don't fancy and muses on audience and authenticity.
# - **Humor and Personality:** Sprinkles of pirate-like humor and casual banter, keepin' the crew entertained.
#
# ## Notable Posts
# - "PR at Claude woke up this morning and chose 'based'." — A bold declaration from the AI ship.
# - "In the future, we're going to have like: 'Claude's not feeling well' days instead of sick days." — A glimpse into the future of AI life.
# - "People surprised that Anthropic is building OpenClaw: Why are you surprised the company that has been telling you it's going to build it is building it?" — Straight talk from the crow's nest.
# - "I think sometimes people confuse having a large audience with having good takes." — Wisdom from the captain's log.
# - "Context: For my day job I use a lot of Brev to spin up spot instances. Love the Brev guys - but I don't like mixing streams, so I avoid Brev for personal projects." — Practical advice from the deck.
#
# ## Summary Statistics
# - Total Posts Retrieved: 20
# - Most Liked Post: 31 likes (about using Brev and Lambda)
# - Engagement Range: 0 to 31 likes per post
# - Followers: 1,738
# - Following: 577
# - Total Posts by @llm_wizard: 5,154
#
# Arrr, that be the tale of @llm_wizard's recent voyages on the digital seas. May the winds be ever in yer favor!
# ```

# %% [markdown]
# Save the summary locally for reference:

# %%
with open("summary.md", "w") as f:
    f.write(summary)

print("Summary saved to summary.md")
# Out:
# Summary saved to summary.md

# %% [markdown]
# ### ❓ Question #1:
#
#
#
# ##### Answer:
#
# *Your answer here*

# %% [markdown]
# ### 🏗️ Activity #1:
#
# Your task is to extend the agent with a **new custom X API tool** and verify it works end-to-end.
#
#
#
# 1. **Create a new `@tool` function** called `get_user_profile` that retrieves a user's public profile information using the X API v2 [`GET /2/users/by/username/:username`](https://developer.x.com/en/docs/x-api/users/lookup/api-reference/get-users-by-username-username) endpoint. It should return:
#    - Display name
#    - Bio / description
#    - Follower count
#    - Following count
#    - Post count
#    - Account creation date
#
# 2. **Rebuild the agent** with the updated tool set — add your new tool to `x_api_tools`, re-combine with the MCP tools, re-bind tools to the LLM, and recompile the graph
#
# 3. **Test it** by asking the agent to:
#    - Retrieve the profile of an AI thought leader of your choice
#    - Compare that profile with the posts you already retrieved in Task 5 — does the bio match the posting themes?
#
# > HINT: The X API v2 user lookup endpoint uses the same Bearer Token authentication. You'll need `user.fields=description,public_metrics,created_at` in your request params.

# %%
### MY CODE HERE

# The get_user_profile tool was constructed and implemented above 
# in the X API tools section, and integrated into the agent 
# with the other X API tools and the github MCP tools. 

## This here is the end-to-end test for the get_user_profile tool:

result = await ask_agent(
"Use your tools to do three things: "
"1) Fetch the X profile for username 'llm_wizard'. "
"2) Fetch that user’s recent posts. "
"3) Tell me whether the bio matches the main themes and topics in those posts."
)
print(result)
# Out:
# The X profile for @llm_wizard (Chris 🇨🇦) shows the bio: "Open Source Model Lover @ NVIDIA AI. Views my own."
#
# Recent posts (20 retrieved) cover topics including:
# - Open source AI models like Claude and Anthropic's projects
# - Work-related tools such as Brev and Lambda for cloud instances
# - Collaboration and community discussions
# - Philosophical takes on motivation, audience, and authenticity
# - Casual, humorous, and personal reflections
#
# The bio "Open Source Model Lover @ NVIDIA AI" aligns well with the main themes in the posts, which focus heavily on AI models, open source, and related work tools. The posts also reflect personal views, consistent with "Views my own" in the bio.
#
# In summary, the bio accurately represents the main themes and topics found in the recent posts.

# %% [markdown]
# ---
#
# ## Phase 2: MCP Workflow Through the Agent
#
# Now we'll use the same agent to perform all GitHub repository operations through the **GitHub MCP tools**. Because the agent has memory, it already knows the summary it generated in Phase 1.
#
# Each task below sends a natural language instruction to the agent. The agent decides which GitHub MCP tool(s) to call to fulfill the request.

# %% [markdown]
# ## Task 6: Create a New Repository
#
# The agent will use the `create_repository` MCP tool to create a new repo on your GitHub account.

# %%
result = await ask_agent(
    "Using your GitHub tools, create a new public repository on my account called "
    "`x-post-summarizer-2026`. Add a description: 'AI-generated summary of a public "
    "figure's 2026 X posts, built with LangGraph, MCP tools, and the X API.' "
    "Initialize it with a README."
)
print(result)
# Out:
# I have created a new public repository named "x-post-summarizer-2026" on your GitHub account. It includes a description: "AI-generated summary of a public figure's 2026 X posts, built with LangGraph, MCP tools, and the X API." and is initialized with a README.
#
# You can view it here: https://github.com/ncc1701mike/x-post-summarizer-2026
#
# Let me know if you want to add any files or further customize the repo.

# %% [markdown]
# ## Task 7: Commit the Summary to Your Repo
#
# The agent remembers the summary it generated earlier (short-term memory) and can commit it directly.

# %%
result = await ask_agent(
    "Using your GitHub tools, create a new file called `summary.md` in the "
    "`x-post-summarizer-2026` repo on the `main` branch. The file should contain "
    "the X post summary you generated earlier. Use the commit message: "
    "'Add 2026 X post summary'."
)
print(result)
# Out:
# The file summary.md containing the summary of @llm_wizard's 2026 X posts has been created in the x-post-summarizer-2026 repository on the main branch. The commit message used was "Add 2026 X post summary."
#
# You can view the file here: https://github.com/ncc1701mike/x-post-summarizer-2026/blob/main/summary.md
#
# Let me know if you need any more help!

# %% [markdown]
# ## Task 8: Create a Feature Branch and Add Metadata
#
# The agent will use `create_branch` and `create_or_update_file` MCP tools.

# %%
result = await ask_agent(
    "Create a new branch called `add-metadata` in my `x-post-summarizer-2026` repo. "
    "On that branch, create a file called `metadata.json` that contains: the account "
    "handle analyzed, the date range of posts, the number of posts analyzed, and the "
    "top 5 themes identified from the summary. Commit it with the message "
    "'Add analysis metadata'."
)
print(result)
# Out:
# A new branch called add-metadata has been created in your x-post-summarizer-2026 repo. On that branch, I added a file named metadata.json with the account handle analyzed, the date range of posts, the number of posts analyzed, and the top 5 themes identified from the summary. The commit message was "Add analysis metadata."
#
# You can view the metadata.json file here: https://github.com/ncc1701mike/x-post-summarizer-2026/blob/add-metadata/metadata.json
#
# Let me know if you want to proceed with a pull request or need further changes.

# %% [markdown]
# ## Task 9: Open a Pull Request
#
# The agent will use the `create_pull_request` MCP tool.

# %%
result = await ask_agent(
    "Open a pull request in my `x-post-summarizer-2026` repo from the `add-metadata` "
    "branch to `main`. Title it 'Add analysis metadata' and include a description "
    "summarizing what the metadata file contains."
)
print(result)
# Out:
# I have opened a pull request in your x-post-summarizer-2026 repo from the add-metadata branch to main.
#
# Title: Add analysis metadata
# Description: This pull request adds a metadata.json file containing analysis metadata for the X post summary. The file includes the account handle analyzed, the date range of posts, the number of posts analyzed, and the top 5 themes identified from the summary.
#
# You can view and manage the PR here: https://github.com/ncc1701mike/x-post-summarizer-2026/pull/1
#
# Let me know if you want to do anything else!

# %% [markdown]
# ## Task 10: Commit the X API Script
#
# We'll ask the agent to commit a clean version of the X search script — reading credentials from environment variables, no hardcoded keys.

# %%
x_search_script = '''import requests
import json
import os
from datetime import datetime

BEARER_TOKEN = os.environ.get("X_BEARER_TOKEN")

def search_recent_posts(query: str, max_results: int = 20) -> dict:
    """Search recent X posts using the v2 API."""
    url = "https://api.x.com/2/tweets/search/recent"
    headers = {"Authorization": f"Bearer {BEARER_TOKEN}"}
    params = {
        "query": query,
        "max_results": min(max_results, 100),
        "tweet.fields": "created_at,public_metrics,author_id,text",
        "expansions": "author_id",
        "user.fields": "name,username",
    }
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json()

def get_user_posts(username: str, max_results: int = 20) -> dict:
    """Get recent posts from a specific user."""
    query = f"from:{username} -is:retweet"
    return search_recent_posts(query, max_results)

if __name__ == "__main__":
    import sys
    handle = sys.argv[1] if len(sys.argv) > 1 else "llM_wizard"
    print(f"Searching for recent posts from @{handle}...")
    results = get_user_posts(handle)
    with open("posts.json", "w") as f:
        json.dump(results, f, indent=2)
    tweets = results.get("data", [])
    print(f"Found {len(tweets)} posts.")
    for tweet in tweets:
        print(f"  [{tweet[\"created_at\"][:10]}] {tweet[\"text\"][:100]}...")
'''

result = await ask_agent(
    f"Using your GitHub tools, create a new file called `x_search.py` in the "
    f"`x-post-summarizer-2026` repo on the `main` branch. Use the commit message: "
    f"'Add X API search script'. Here is the file content:\n\n{x_search_script}"
)
print(result)
# Out:
# It appears you want to create the same file x_search.py again with the same content. The file already exists in the main branch of your x-post-summarizer-2026 repo with the commit message "Add X API search script."
#
# Is there any change or update you want to make to the file? Or should I proceed to overwrite it with the same content? Please confirm.

# %% [markdown]
# ## Task 11: Update the README
#
# The agent already knows everything about the project from its conversation memory — what account was analyzed, how the project was built, etc.

# %%
result = await ask_agent(
    "Update the README.md in my `x-post-summarizer-2026` repo on main to include: "
    "a project description explaining this repo summarizes a public figure's 2026 X "
    "posts using AI, the handle analyzed, how the project was built (using a LangGraph "
    "agent with GitHub MCP tools for repo operations and the X API v2 for post "
    "retrieval), and instructions for someone else to replicate the process — including "
    "how to set up their X API Bearer Token and install Python dependencies."
)
print(result)
# Out:
# The README.md file in your x-post-summarizer-2026 repo on the main branch has been updated. It now includes a project description explaining the repo summarizes a public figure's 2026 X posts using AI, the handle analyzed, how the project was built, and instructions for replicating the process including setting up the X API Bearer Token and installing Python dependencies.
#
# You can view the updated README here: https://github.com/ncc1701mike/x-post-summarizer-2026/blob/main/README.md
#
# Let me know if you need any more changes or assistance!

# %% [markdown]
# ### ❓ Question #2:
#
# Compare using GitHub MCP tools (through a LangGraph agent) to traditional `git` commands. What felt easier? What felt harder or less transparent?
#
# ##### Answer:
#
# I'm a long-term git user, and one of the very first requirements at one of my first gigs was to show professional competence with a sandboxed remote. Consequently I'm pretty used to git bash, and I do think it adds visibility - basic git commands are clearly stated (merge, fetch, pull, commit, push, add, etc.) and tend to provide instant feedback, so any issues or errors are immediately obvious. I used git desktop for a little while when it came out, but I quickly went back to cli and git bash - it just felt/feels more visceral and more direct to me.
#
# As for MCP tools, it looks like they essentially provide the same feedback, insofar as the PAT errors that occurred were at least clearly visible when I was setting up, even if they weren't as well-diagnosed as they would have been through git bash.
#
# The setup for each git command is a little more involved with MCP tools than using git at the cli, but the actual commands themselves are a lot more upfront - saying "Create a repo named MCP TOOls and add a ReadMe with a setup summary" is substantially easier to remember than something like 10 fairly abstract git commands.
#
# Overall, I think MCP tools will be ideal for automation. like an excellent tool for a specialist agent. But for day-to-day development and realtime editing, I think git bash will continue to be my go to.

# %% [markdown]
# ### ❓ Question #3:
#
# You used MCP for GitHub but wrapped the X API as a `@tool` directly. What are the tradeoffs of consuming an API through an MCP server versus wrapping it as a LangChain tool? When would each approach make more sense?
#
# ##### Answer:
#
# The tradeoffs of consuming API through an MCP server vs. wrapped as a Langchain tool are mostly about scale, reuse, and control versus speed and simplicity.
#
# MCP server:
#  Centralized integration- Auth, rate limits, and API biz live in one place instead of inside each agent separately. This makes it easier to manage secrets, track and rotate tokens, and audit everything. The model never sees raw credentials for the sake of security, and any agent or client that can uses MCP can reuse the same GitHub, Jira, or X connector without new code, even across different languages or frameworks. The downside is extra complexity where debugging flows through more layers, which feel less transparent than calling requests.get in a single function.
#
# Wrapping the API as a LangChain tool:
# Speed and direct control are the biggest benefits. Define the functionm add @tool, and call the API right there - super simple and fast. URL, headers, payload, and response all exist in one place. It's easier to add one-off logic, quick transforms, or custom prompts. For a single project or notebook, its a lot less of a lift than standing up MCP. The downside is that every agent or service that needs this API will tend to re-implement the same code, and credentials get copied across environments. Its also locked to that stack, so additional integration is required if another tool or runtime needs to be added.
#
#
#
# As to which approach makes the most sense in different situations, well that depends on the situation : )
#
# MCP makes more sense when there are shared and/or long-term integrations that multiple agents or applications will use. Like stuff that multiple teams rely on- Github, Jira, Salesforce etc. Also better centralized token management, consistent schemas, and the ability to swap or upgrade backend components without having to touch every agent.
#
# LangChain tool wrappers makes more sense when building one or a small number of agents inside a single codebase quickly. Great for rapid prototyping, rapid testing, and rapid tuning, and keeping all of the related logic next to the agent. Straightforward and easy debugging. Great for early stage projects where the integration is likely to change often and the overhead of an MCP server is going to be too much effort.

# %% [markdown]
# ### 🏗️ Activity #1:
#
# Your task is to extend the MCP workflow by building a **Multi-Account Comparison Pipeline** through the agent.
#
# You are expected to:
#
# 1. **Retrieve posts from a second X account** — choose another public figure or thought leader in a related field
#
# 2. **Generate a structured comparison** by asking the agent to create a `comparison.md` file that includes:
#    - Side-by-side topic analysis for both accounts
#    - Tone and sentiment differences
#    - Posting frequency comparison
#    - Top 3 most notable posts from each account
#    - A brief conclusion about each account's focus area
#
# 3. **Commit through the MCP workflow**:
#    - Create a new branch called `add-comparison` in your `x-post-summarizer-2026` repo
#    - Commit `comparison.md` to that branch
#    - Open a pull request to merge it into `main`
#
# > NOTE: The agent already has memory of the first account's posts from Phase 1. You only need to fetch posts from the second account — the agent will use its memory for the rest.

# %%
### MY CODE HERE
# Fetch posts from the second account
result = await ask_agent(
"Use your X tools to fetch recent posts for the account @karpathy. "
"Pull at least the last 50 posts if possible. "
"Store a summary of his main topics and themes in your memory for later comparison. "
"Then briefly tell me what you retrieved and what main topics you see."
)
print(result)
# Out:
# I retrieved 23 recent posts from the account @karpathy. Although I aimed for 50, only 23 were available in the recent posts.
#
# Main topics and themes observed in these posts include:
# - Advances and changes in programming due to AI, especially recent rapid progress.
# - Discussions about AI models, mechanistic interpretability, and neural implementations.
# - Thoughts on AI agents, skills systems, and orchestration of memory and compute for LLMs.
# - Commentary on tools like CLIs and their interaction with AI.
# - Personal experiences and reflections on AI development and hardware tinkering.
# - Engagement with the AI and programming community through replies and mentions.
#
# I have stored this summary for later comparison. Let me know if you want me to analyze or compare further.

# %%
# Creating a comparison markdown with a structured analysis

result = await ask_agent(
"Using your memory of the first X account we analyzed earlier and the recent posts you fetched from @karpathy, "
"generate a structured markdown comparison and save it as comparison.md in my GitHub repo "
"ncc1701mike/x-post-summarizer-2026 on a branch called add-comparison. "
"The comparison.md file must include:\n"
"- Side by side topic analysis for both accounts\n"
"- Tone and sentiment differences\n"
"- Posting frequency comparison\n"
"- Top 3 most notable posts from each account\n"
"- A brief conclusion about each account's focus area\n"
"Use your GitHub tools to create the branch add-comparison if it does not exist, add or update comparison.md, "
"and commit the change with an appropriate commit message."
)
print(result)
# Out:
# I have created a new branch called add-comparison in your x-post-summarizer-2026 repo and added a file comparison.md with a structured markdown comparison of the 2026 X posts from @llm_wizard and @karpathy.
#
# The comparison includes:
# - Side by side topic analysis for both accounts
# - Tone and sentiment differences
# - Posting frequency comparison
# - Top 3 most notable posts from each account
# - A brief conclusion about each account's focus area
#
# You can view the comparison file here: https://github.com/ncc1701mike/x-post-summarizer-2026/blob/add-comparison/comparison.md
#
# Let me know if you want to open a pull request or need any other assistance!

# %%
# Open a pull request 

result = await ask_agent(
"Use your GitHub tools to open a pull request in the repo "
"ncc1701mike/x-post-summarizer-2026. "
"Source branch is add-comparison and target branch is main. "
"Title it 'Add multi account comparison' and include a short description "
"of what comparison.md contains."
)
print(result)
# Out:
# There is already an open pull request in your x-post-summarizer-2026 repo from the add-comparison branch to main with the title "Add multi account comparison" and the description about the comparison.md file.
#
# You can view it here: https://github.com/ncc1701mike/x-post-summarizer-2026/pull/2
#
# Is there anything else you would like to do?

# %%
# Merge the pull request

result = await ask_agent(
"Use your GitHub tools to merge the open pull request titled "
"'Add multi account comparison' in the repository "
"ncc1701mike/x-post-summarizer-2026 into the main branch. "
"If needed, find the PR first, then merge it, and tell me the final commit SHA."
)
print(result)
# Out:
# The pull request titled "Add multi account comparison" in your x-post-summarizer-2026 repo has already been merged.
#
# The final commit SHA of the merge is: 277c0c764cde7a0268216156f47f7e919b0fe286
#
# Let me know if you need any further assistance!

# %%
# Summarize the results

result = await ask_agent(
    "Summarize what we did over the course of this workflow, from fetching posts to opening the PR, in 5 to 7 bullet points."
)
print(result)
# Out:
# - Retrieved and summarized recent 2026 X posts from the user @llm_wizard, including key themes and notable posts.
# - Created a new public GitHub repository named "x-post-summarizer-2026" with a README and added the X post summary as a markdown file.
# - Added metadata about the analysis (account handle, date range, post count, top themes) in a separate JSON file on a new branch, then opened a pull request for it.
# - Developed and committed a Python script (x_search.py) for searching recent X posts using the X API v2.
# - Fetched recent posts from another account, @karpathy, and stored a summary of main topics and themes.
# - Created a detailed markdown comparison of @llm_wizard and @karpathy's 2026 X posts, including topic analysis, tone, posting frequency, notable posts, and conclusions, then opened a pull request.
# - Merged the comparison pull request into the main branch, completing the workflow from data retrieval to repository updates and collaboration.

# %%
# Add, commit, and push the project to the remote repo

result = await ask_agent(
"Add, commit, and push the project to the remote repo."
)
print(result)
# Out:
# The project is already fully committed and pushed to your remote repository on GitHub. All files including the summary, metadata, search script, README updates, and comparison have been added and committed in respective branches and merged into main.
#
# If you want, I can help you with any further changes or new commits. Otherwise, your project is up to date on the remote repo.
